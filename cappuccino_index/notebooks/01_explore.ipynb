# %%
import pandas as pd

RAW_PATH = "/home/sebas/data/capuccinoIndex/Cappuccino Index 2026 (public).xlsx"

full_data = pd.read_excel(RAW_PATH, sheet_name="full_data").dropna(axis=1, how="all")
capp_index_all_countries = pd.read_excel(RAW_PATH, sheet_name="capp_index_all_countries").dropna(axis=1, how="all")
index_n10 = pd.read_excel(RAW_PATH, sheet_name="index_(n\u226510)").dropna(axis=1, how="all")

# %%
full_data.shape, full_data.dtypes
# Out:
# ((2594, 8),
#  Currency                           str
#  Hourly wage                    float64
#  Price per small cappuccino     float64
#  Country                            str
#  City                               str
#  Urban classification               str
#  Hourly wage in GBP             float64
#  Price per cappuccino in GBP    float64
#  dtype: object)

# %%
full_data.head()
# Out:
#               Currency  Hourly wage  Price per small cappuccino      Country  \
# 0   DKK - Danish Krone       140.00                        90.0      Denmark
# 1  CNY - Yuan Renminbi        30.00                        86.0        China
# 2      USD - US dollar        17.88                        12.0          USA
# 3    CHF - Swiss Franc        26.70                         9.0  Switzerland
# 4   DKK - Danish Krone       140.00                        65.0      Denmark
#
#             City Urban classification  Hourly wage in GBP  \
# 0     Copenhagen                Urban           16.042348
# 1       Shenzhen                Urban            3.295239
# 2  West Richland             Suburban           13.253550
# 3     St. Moritz                Rural           24.493378
# 4     Copenhagen                Urban           16.042348
#
#    Price per cappuccino in GBP
# 0                    10.312938
# 1                     9.446352
# 2                     8.895000
# 3                     8.256195
# 4                     7.448233

# %%
capp_index_all_countries.shape, capp_index_all_countries.head()
# Out:
# ((87, 4),
#       Country  Index Number    Time (mm:ss)  Data Entries
#  0    Algeria     86.665126 0 days 01:26:40             1
#  1  Argentina     60.244479 0 days 01:00:15            22
#  2    Armenia     52.000000 0 days 00:52:00             1
#  3  Australia     10.067114 0 days 00:10:04           171
#  4    Austria     19.022154 0 days 00:19:01            13)

# %%
index_n10.shape, index_n10.head()
# Out:
# ((36, 4),
#         Country  Index Number           Time (mm:ss)  Data Entries
#  0    Australia     10.067114 0 days 00:10:04.027000           171
#  1        Italy     11.849530 0 days 00:11:50.972000            15
#  2  New Zealand     12.755556 0 days 00:12:45.333000            35
#  3  Switzerland     14.389251 0 days 00:14:23.355000            18
#  4  Netherlands     14.879107 0 days 00:14:52.746000            73)
