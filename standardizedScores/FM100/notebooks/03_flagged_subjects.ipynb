# %% [markdown]
# # M2: MET020, MET047, MET021
#
# `PLANScores.md` M2: dedicated plots for three specific subjects -- MET020 (the example subject `01_explore.ipynb` already used for the smoothing-window demo), and the project's two flagged "different deficiency" cases (`docs/findings.md` section 1): MET047 (new, no SSVEP/behavioral data, errors evenly split red-green/blue-yellow instead of the classic CVD pattern) and MET021 (labeled CTR from the SSVEP side, but scores well above the CTR mean here).
#
# Each shown linear, then radial with both label modes (`'angle'` default, `'cap'` -- M2's new FM100-diagram-convention labels: the tick sequence starts at 85, not 1).

# %%
import sys
sys.path.append('../scripts')

import loader
import plotting

df = loader.load_fm100_raw()
flagged = ['MET020', 'MET047', 'MET021']

# %% [markdown]
# ## MET020

# %%
plotting.plot_subject_fm100(df, 'MET020', kind='linear');

# %%
plotting.plot_subject_fm100(df, 'MET020', kind='radial', label_mode='cap');

# %% [markdown]
# ## MET047

# %%
plotting.plot_subject_fm100(df, 'MET047', kind='linear');

# %%
plotting.plot_subject_fm100(df, 'MET047', kind='radial', label_mode='cap');

# %% [markdown]
# ## MET021

# %%
plotting.plot_subject_fm100(df, 'MET021', kind='linear');

# %%
plotting.plot_subject_fm100(df, 'MET021', kind='radial', label_mode='cap');

# %% [markdown]
# ## All three together

# %%
plotting.plot_group_fm100(df, [
    {'label': sub_id, 'sub_ids': [sub_id]} for sub_id in flagged
], kind='radial', label_mode='cap', window=5);
# Out:
# /home/sebas/projects/DataAnalysis/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:219: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/sebas/projects/DataAnalysis/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:208: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
